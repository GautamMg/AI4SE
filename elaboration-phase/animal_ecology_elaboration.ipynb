# %% [markdown]
# # Project context

# %% [markdown]
# Below is a sample diagram, my team member had drew to depict the entire flow of the project.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #ChatGPT

# %% [markdown]
# ## Component View Diagram

# %% [markdown]
# ![Untitled diagram-2025-10-12-193959.png](data:image/png;base64,...)

# %% [markdown]
# ## Deployment & Dataflow diagram

# %% [markdown]
# ![Untitled diagram-2025-10-12-194501.png](data:image/png;base64,...)

# %% [markdown]
# # Google Gemini

# %% [markdown]
# ## System Architecture Diagram

# %% [markdown]
# ![Untitled diagram-2025-10-12-195222.png](data:image/png;base64,...)

# %% [markdown]
# ## End-to-End flowchart diagram

# %% [markdown]
# ![Untitled diagram-2025-10-12-195700.png](data:image/png;base64,...)

# %% [markdown]
# #Miro

# %% [markdown]
# ## Flow chart diagram

# %% [markdown]
# ![Flowchart (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Lucidchart + Lucid AI

# %% [markdown]
# ## Flow chart Diagram

# %% [markdown]
# ![Blank diagram.jpeg](data:image/jpeg;base64,...)
