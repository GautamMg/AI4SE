# %% [markdown]
# <h1>ChatGPT</h1>

# %% [markdown]
# ### 4.2.3 AO-OCT – Design Support
#
# **A. System Architecture Diagram**
# Link: [Open FigJam Architecture Diagram](https://www.figma.com/board/RtKHYcpKdhfjGToyXoArF6/AO-OCT-End-to-End-Flow-Chart?node-id=0-1&p=f)
#
# **B. End-to-End Flow Chart**
# Link: [Open FigJam Flow Diagram](https://www.figma.com/board/t8GE8yQ6UssKYjoruy7Qyd/AO-OCT-System-Architecture-Diagram?node-id=0-1&p=f)

# %% [markdown]
# <h1>Gemini</h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # End to End flow

# %% [markdown]
# ![image.png](data:image/png;base64,...)
